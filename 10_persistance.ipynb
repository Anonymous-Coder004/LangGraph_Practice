# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langgraph.checkpoint.memory import InMemorySaver

# %%
load_dotenv()
llm =ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
class JokeState(TypedDict):

    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

def generate_explanation(state: JokeState):

    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return {'explanation': response}

# %%
graph = StateGraph(JokeState)

graph.add_node('generate_joke', generate_joke)
graph.add_node('generate_explanation', generate_explanation)

graph.add_edge(START, 'generate_joke')
graph.add_edge('generate_joke', 'generate_explanation')
graph.add_edge('generate_explanation', END)

checkpointer = InMemorySaver() #this will ensure that all state values will get store at checkpoints

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'pizza'}, config=config2) #state value will get saved in corresponding to thread id2
# Out:
# {'topic': 'pizza',
#  'joke': 'Why did the pizza chef go broke?\nBecause he kept *making* too much dough!',
#  'explanation': 'This joke is a classic pun that plays on the double meaning of the word "dough."\n\nHere\'s the breakdown:\n\n1.  **"Dough" (Meaning 1 - Literal):** In the context of a pizza chef, "dough" refers to the mixture of flour, water, and yeast that is flattened and topped to make a pizza. A chef *makes* dough as part of their job.\n\n2.  **"Dough" (Meaning 2 - Slang):** "Dough" is also a common slang term for **money**. If someone has a lot of "dough," they\'re rich. If you need "dough," you need money.\n\n**How the joke works:**\n\n*   When you hear, "Why did the pizza chef go broke?", your mind immediately thinks about financial problems, and therefore, "dough" in the sense of **money**.\n*   The punchline, "Because he kept *making* too much dough!", deliberately plays on this expectation. Instead of implying he literally made too much *money* (which would make him rich, not broke), it refers to him physically producing excessive amounts of *pizza dough*.\n\nThe humor comes from the unexpected twist – you\'re expecting a financial explanation, but you get a literal, food-related one, creating a silly image of a chef surrounded by mountains of unbaked pizza dough while still being out of money.'}

# %%
workflow.get_state(config1) # it prints final state VALUE for config1 which has thread id 1 hence pasta joke
# Out:
# StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta break up with the sauce?\n\nBecause it was an **impasta**!', 'explanation': 'This is a classic example of a **pun**, which relies on wordplay for its humor.\n\nHere\'s the breakdown:\n\n1.  **The Setup:** "Why did the pasta break up with the sauce?" This gives human characteristics (having a relationship, breaking up) to food items. This is a common setup for jokes, especially puns.\n\n2.  **The Punchline:** "Because it was an **impasta**!"\n    *   **"Impasta"** sounds exactly like the word **"impostor."**\n    *   An **impostor** is someone who pretends to be someone else to deceive them; a fraud or a fake.\n\n3.  **The Joke\'s Logic:** The humor comes from combining these ideas. The pasta was acting like an "impostor" – meaning it was being fake, not genuine, or perhaps pretending to be something it wasn\'t in its "relationship" with the sauce. And just like a person might break up with someone who isn\'t genuine, the sauce "broke up" with the pasta for being an "impasta."\n\nIt\'s a silly, lighthearted joke that relies entirely on that clever phonetic similarity!'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b3-a18c-6167-8004-439637c784f3'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-20T08:09:37.390201+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b3-5e68-618c-8003-2288c2beb9fa'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2)) #it shows both final intermediate state values for config 2 means thread_id 2 hence pizza joke
# Out:
# [StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef go broke?\nBecause he kept *making* too much dough!', 'explanation': 'This joke is a classic pun that plays on the double meaning of the word "dough."\n\nHere\'s the breakdown:\n\n1.  **"Dough" (Meaning 1 - Literal):** In the context of a pizza chef, "dough" refers to the mixture of flour, water, and yeast that is flattened and topped to make a pizza. A chef *makes* dough as part of their job.\n\n2.  **"Dough" (Meaning 2 - Slang):** "Dough" is also a common slang term for **money**. If someone has a lot of "dough," they\'re rich. If you need "dough," you need money.\n\n**How the joke works:**\n\n*   When you hear, "Why did the pizza chef go broke?", your mind immediately thinks about financial problems, and therefore, "dough" in the sense of **money**.\n*   The punchline, "Because he kept *making* too much dough!", deliberately plays on this expectation. Instead of implying he literally made too much *money* (which would make him rich, not broke), it refers to him physically producing excessive amounts of *pizza dough*.\n\nThe humor comes from the unexpected twist – you\'re expecting a financial explanation, but you get a literal, food-related one, creating a silly image of a chef surrounded by mountains of unbaked pizza dough while still being out of money.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-caf3-6c95-8006-861d9c9268dc'}}, metadata={'source': 'loop', 'step': 6, 'parents': {}}, created_at='2025-12-20T08:10:35.418906+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-8f59-63c9-8005-61fa90566e1c'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pizza chef go broke?\nBecause he kept *making* too much dough!', 'explanation': 'This joke is a classic **pun**!\n\nHere\'s why it\'s funny:\n\n1.  **"Impasta" sounds like "Impostor":** The word "impasta" is a direct play on the word "impostor."\n2.  **What\'s an "Impostor"?** An impostor is someone who pretends to be someone else in order to deceive. People who commit fraud or deception by being an impostor can, and often do, get arrested.\n3.  **The "Pasta" Connection:** The first part of the joke sets up the subject as "pasta." The punchline then uses a word that literally *contains* "pasta" ("im-**pasta**") while sounding like the word for someone who would get arrested ("impostor").\n\nSo, the humor comes from the clever wordplay that takes a food item (pasta) and gives it a silly, human characteristic (being an impostor) that would lead to arrest, all by using a word that sounds almost identical to the real reason someone might be arrested.'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-8f59-63c9-8005-61fa90566e1c'}}, metadata={'source': 'loop', 'step': 5, 'parents': {}}, created_at='2025-12-20T08:10:29.169019+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-2a44-63e0-8004-61c1bd501895'}}, tasks=(PregelTask(id='492058d3-4862-7c0f-90c0-13aa9c1a0de2', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic pun that plays on the double meaning of the word "dough."\n\nHere\'s the breakdown:\n\n1.  **"Dough" (Meaning 1 - Literal):** In the context of a pizza chef, "dough" refers to the mixture of flour, water, and yeast that is flattened and topped to make a pizza. A chef *makes* dough as part of their job.\n\n2.  **"Dough" (Meaning 2 - Slang):** "Dough" is also a common slang term for **money**. If someone has a lot of "dough," they\'re rich. If you need "dough," you need money.\n\n**How the joke works:**\n\n*   When you hear, "Why did the pizza chef go broke?", your mind immediately thinks about financial problems, and therefore, "dough" in the sense of **money**.\n*   The punchline, "Because he kept *making* too much dough!", deliberately plays on this expectation. Instead of implying he literally made too much *money* (which would make him rich, not broke), it refers to him physically producing excessive amounts of *pizza dough*.\n\nThe humor comes from the unexpected twist – you\'re expecting a financial explanation, but you get a literal, food-related one, creating a silly image of a chef surrounded by mountains of unbaked pizza dough while still being out of money.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pizza', 'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!', 'explanation': 'This joke is a classic **pun**!\n\nHere\'s why it\'s funny:\n\n1.  **"Impasta" sounds like "Impostor":** The word "impasta" is a direct play on the word "impostor."\n2.  **What\'s an "Impostor"?** An impostor is someone who pretends to be someone else in order to deceive. People who commit fraud or deception by being an impostor can, and often do, get arrested.\n3.  **The "Pasta" Connection:** The first part of the joke sets up the subject as "pasta." The punchline then uses a word that literally *contains* "pasta" ("im-**pasta**") while sounding like the word for someone who would get arrested ("impostor").\n\nSo, the humor comes from the clever wordplay that takes a food item (pasta) and gives it a silly, human characteristic (being an impostor) that would lead to arrest, all by using a word that sounds almost identical to the real reason someone might be arrested.'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-2a44-63e0-8004-61c1bd501895'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2025-12-20T08:10:18.569810+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-2a42-6255-8003-fc59531300c6'}}, tasks=(PregelTask(id='ccccae10-c362-4052-f5e4-fd0fbc5fab5c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pizza chef go broke?\nBecause he kept *making* too much dough!'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!', 'explanation': 'This joke is a classic **pun**!\n\nHere\'s why it\'s funny:\n\n1.  **"Impasta" sounds like "Impostor":** The word "impasta" is a direct play on the word "impostor."\n2.  **What\'s an "Impostor"?** An impostor is someone who pretends to be someone else in order to deceive. People who commit fraud or deception by being an impostor can, and often do, get arrested.\n3.  **The "Pasta" Connection:** The first part of the joke sets up the subject as "pasta." The punchline then uses a word that literally *contains* "pasta" ("im-**pasta**") while sounding like the word for someone who would get arrested ("impostor").\n\nSo, the humor comes from the clever wordplay that takes a food item (pasta) and gives it a silly, human characteristic (being an impostor) that would lead to arrest, all by using a word that sounds almost identical to the real reason someone might be arrested.'}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b5-2a42-6255-8003-fc59531300c6'}}, metadata={'source': 'input', 'step': 3, 'parents': {}}, created_at='2025-12-20T08:10:18.568951+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-80d9-6ea2-8002-dc7296542c39'}}, tasks=(PregelTask(id='dd5c07b8-f89b-33a0-54ea-2487f9c96726', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pizza'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!', 'explanation': 'This joke is a classic **pun**!\n\nHere\'s why it\'s funny:\n\n1.  **"Impasta" sounds like "Impostor":** The word "impasta" is a direct play on the word "impostor."\n2.  **What\'s an "Impostor"?** An impostor is someone who pretends to be someone else in order to deceive. People who commit fraud or deception by being an impostor can, and often do, get arrested.\n3.  **The "Pasta" Connection:** The first part of the joke sets up the subject as "pasta." The punchline then uses a word that literally *contains* "pasta" ("im-**pasta**") while sounding like the word for someone who would get arrested ("impostor").\n\nSo, the humor comes from the clever wordplay that takes a food item (pasta) and gives it a silly, human characteristic (being an impostor) that would lead to arrest, all by using a word that sounds almost identical to the real reason someone might be arrested.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-80d9-6ea2-8002-dc7296542c39'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2025-12-20T08:08:13.431147+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-4c04-61fb-8001-f1a4d43b52c2'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta', 'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!'}, next=('generate_explanation',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-4c04-61fb-8001-f1a4d43b52c2'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2025-12-20T08:08:07.890971+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-1256-6a4f-8000-acadefcd1518'}}, tasks=(PregelTask(id='758770a7-79cb-7992-7634-2ab9eb3e2656', name='generate_explanation', path=('__pregel_pull', 'generate_explanation'), error=None, interrupts=(), state=None, result={'explanation': 'This joke is a classic **pun**!\n\nHere\'s why it\'s funny:\n\n1.  **"Impasta" sounds like "Impostor":** The word "impasta" is a direct play on the word "impostor."\n2.  **What\'s an "Impostor"?** An impostor is someone who pretends to be someone else in order to deceive. People who commit fraud or deception by being an impostor can, and often do, get arrested.\n3.  **The "Pasta" Connection:** The first part of the joke sets up the subject as "pasta." The punchline then uses a word that literally *contains* "pasta" ("im-**pasta**") while sounding like the word for someone who would get arrested ("impostor").\n\nSo, the humor comes from the clever wordplay that takes a food item (pasta) and gives it a silly, human characteristic (being an impostor) that would lead to arrest, all by using a word that sounds almost identical to the real reason someone might be arrested.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-1256-6a4f-8000-acadefcd1518'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-20T08:08:01.843039+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-1253-6f7d-bfff-af70370e2f59'}}, tasks=(PregelTask(id='cce00e6a-0079-b7ba-4565-dbab7fb0120c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-1253-6f7d-bfff-af70370e2f59'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2025-12-20T08:08:01.841953+00:00', parent_config=None, tasks=(PregelTask(id='f158ddcd-0c1a-11e4-a051-2b5af958816c', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'pasta'}),), interrupts=())]

# %% [markdown]
# Time Travel

# %%
workflow.get_state({"configurable": {"thread_id": "2", "checkpoint_id": "1f0dd7b0-1256-6a4f-8000-acadefcd1518"}})
# Out:
# StateSnapshot(values={'topic': 'pasta'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_id': '1f0dd7b0-1256-6a4f-8000-acadefcd1518'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2025-12-20T08:08:01.843039+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0dd7b0-1253-6f7d-bfff-af70370e2f59'}}, tasks=(PregelTask(id='cce00e6a-0079-b7ba-4565-dbab7fb0120c', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the pasta get arrested?\n\nBecause it was an **impasta**!'}),), interrupts=())

# %%
workflow.invoke(None, {"configurable":{"thread_id": "2", "checkpoint_id": "1f0dd7b0-1256-6a4f-8000-acadefcd1518"}})
# Out:
# {'topic': 'pasta',
#  'joke': 'Why did the pasta get in trouble?\n\nBecause it was an **impasta**!',
#  'explanation': 'This is a classic pun-based joke!\n\nIt works by playing on the similarity in sound between two words: **"impasta"** and **"impostor"**.\n\nLet\'s break it down:\n\n1.  **Impostor:** This is the real word. An impostor is a person who pretends to be someone else in order to deceive others, especially for fraudulent purposes. Someone who is an impostor would definitely "get in trouble."\n\n2.  **Impasta:** This is the made-up word for the joke. It takes the word "pasta" (the food) and adds the prefix "im-" to make it sound exactly like "impostor."\n\n**The Joke\'s Humor:**\nThe humor comes from the absurd substitution. We\'re talking about actual pasta (the food), but the punchline gives it the characteristics of an "impostor" because of the sound-alike word. It\'s unexpected and silly to imagine a bowl of spaghetti pretending to be someone else and getting arrested for it!\n\n**In short:** The pasta got in trouble because it was a fake, a deceiver... an "impasta" instead of an "impostor"!'}

# %% [markdown]
# updating state

# %%
workflow.update_state({"configurable": {"thread_id": "1", "checkpoint_id": "1f0dd7b0-1256-6a4f-8000-acadefcd1518", "checkpoint_ns": ""}}, {'topic':'samosa'})
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0ddb67-6f9c-63e8-8000-574f83bbb183'}}
