# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
#create state
class LLMstate(TypedDict):
    ques:str 
    ans:str

# %%
def llm_qa(state:LLMstate)->LLMstate:
    ques=state['ques']
    prompt=f'Answer the following question {ques}'
    ans=model.invoke(prompt).content
    state['ans']=ans
    return state

# %%
graph=StateGraph(LLMstate)
graph.add_node('llm_qa',llm_qa)
graph.add_edge(START,'llm_qa')
graph.add_edge('llm_qa',END)
workflow=graph.compile()

# %%
initial_state={'ques':'explain the pleasure after masturbation for both men and women in consise manner?'}
final_state=workflow.invoke(initial_state)
print(final_state['ans'])
# Out:
# For both men and women, the pleasure experienced after masturbation is primarily due to a profound release of physical and psychological tension, coupled with a powerful neurochemical response in the brain.
#
# Key elements of this pleasure include:
#
# 1.  **Neurochemical Flood:** Orgasm triggers the release of several key neurochemicals:
#     *   **Dopamine:** A "reward" hormone that creates feelings of intense pleasure and satisfaction.
#     *   **Oxytocin:** Often called the "bonding hormone," it promotes feelings of calm, well-being, and connection (even if self-directed).
#     *   **Endorphins:** Natural pain relievers that induce euphoria and a general sense of contentment.
#     *   **Prolactin:** Associated with feelings of satiety, relaxation, and often, post-orgasmic sleepiness.
# 2.  **Physical Relaxation:** Following the rhythmic muscle contractions of orgasm, the body experiences widespread muscle relaxation, contributing to a feeling of limpness and ease.
# 3.  **Psychological Relief:** The culmination of sexual tension in orgasm provides significant mental relief, reducing stress and anxiety, and leaving a sense of calm and contentment.
#
# In essence, it's a profound feeling of **satisfaction, relaxation, and emotional calm** driven by a potent cocktail of "feel-good" brain chemicals and the release of accumulated physical tension. This experience is largely similar for both men and women.
