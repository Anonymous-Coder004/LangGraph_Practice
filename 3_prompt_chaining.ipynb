# %%
from langgraph.graph import StateGraph,START,END
from langchain_google_genai import ChatGoogleGenerativeAI
from typing import TypedDict
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
model=ChatGoogleGenerativeAI(model='gemini-2.5-flash')

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state['content'])
# Out:
# **India's Intelligent Revolution: Unpacking the Rise of Artificial Intelligence**
#
# **Meta Description:** Explore the exponential growth of Artificial Intelligence in India, driven by government initiatives, a thriving startup ecosystem, and a vast talent pool. Discover its impact across sectors, the challenges it faces, and its promising future.
#
# ---
#
# ## I. Introduction: India at the AI Crossroads
#
# The world stands on the precipice of an Artificial Intelligence revolution, a transformative wave reshaping industries, economies, and societies globally. In this dynamic landscape, India is rapidly emerging not just as a significant consumer but as a formidable developer and innovator, carving out a unique and influential position. With its unparalleled blend of technological prowess, a massive and diverse population, and a burgeoning digital infrastructure, India is poised to redefine its digital future through AI.
#
# Why now? The conditions are ripe for what many call "the perfect storm" for AI in India. Ambitious "Digital India" initiatives have dramatically increased internet penetration, especially in rural areas, while the widespread adoption of digital services generates an ocean of data. Coupled with a vast, tech-savvy youth population eager to innovate, India has all the ingredients for an AI renaissance.
#
# This blog post will delve into the multifaceted rise of Artificial Intelligence in India, exploring the key drivers propelling its growth, its profound impact across various sectors, the critical challenges that need addressing, and the exciting future that awaits this intelligent nation. Get ready to understand the forces shaping India's AI journey, its current applications, and the vision for an AI-powered tomorrow.
#
# ## II. The Catalysts: Why AI is Flourishing in India
#
# The rapid ascent of AI in India is no accident; it’s the result of a concerted effort and convergence of favorable circumstances.
#
# ### A. Government Push and Policy Frameworks
# The Indian government has recognized AI's potential as a strategic national imperative.
# *   **NITI Aayog's "National Strategy for AI":** This seminal document outlined a vision focusing on "AI for All," emphasizing inclusive growth and leveraging AI for social good. It identified key focus areas: healthcare, agriculture, education, smart cities, and infrastructure.
# *   **"AI for All" Vision:** The philosophy behind India's AI strategy is to ensure that the benefits of AI are accessible and impactful across all segments of society, addressing unique Indian challenges.
# *   **RAISE (Responsible AI for Social Empowerment) Summit:** India has actively promoted ethical and responsible AI development through platforms like the RAISE summit, fostering dialogue on trustworthy AI.
# *   **Data Protection & Privacy Bills:** Efforts are underway to establish robust data protection and privacy frameworks, crucial for building trust and ensuring responsible data-driven AI innovation.
#
# ### B. The Startup Boom & Innovation Hubs
# India's entrepreneurial spirit has found a fertile ground in AI.
# *   **Thriving Startup Ecosystem:** Cities like Bengaluru, Delhi-NCR, Hyderabad, and Pune have become vibrant innovation hubs, fostering hundreds of AI-focused startups.
# *   **Increased Funding & Investment:** Both domestic and international venture capital funds are aggressively investing in Indian AI startups, recognizing their potential for disruption and scale. Companies across SaaS, healthcare, agritech, and fintech are attracting significant capital.
# *   **Key Indian Players/Startups:** While specific names are constantly evolving, India boasts innovative AI companies developing solutions ranging from predictive analytics for healthcare to AI-powered educational platforms and vernacular language processing.
#
# ### C. A Deep Talent Pool
# India's demographic dividend plays a significant role in its AI growth.
# *   **Abundance of STEM Graduates:** India produces a vast number of engineers, data scientists, and technology professionals annually, forming a robust talent pipeline for AI development.
# *   **Growing AI/ML Education:** Universities, online platforms, and bootcamps are rapidly expanding specialized courses in AI and Machine Learning, equipping the workforce with cutting-edge skills.
# *   **Return of NRI Talent:** A growing trend sees Indian tech professionals, after gaining invaluable experience in global AI powerhouses, returning to India, bringing world-class expertise and fostering local innovation.
#
# ### D. Digital Transformation & Data Availability
# The "Digital India" movement has created an unprecedented data ecosystem.
# *   **Digital India & UPI:** The massive adoption of digital payments via UPI (Unified Payments Interface) and other digital services generates an immense volume of transactional data, perfect for training AI models.
# *   **Aadhaar and India Stack:** India's foundational digital public infrastructure, including Aadhaar (unique identity) and the wider India Stack, provides a secure and verifiable digital identity layer that enables a myriad of AI applications across various sectors.
# *   **Smartphone Penetration:** Widespread smartphone ownership ensures broad access to digital services and platforms, fueling data generation and AI adoption.
#
# ### E. Global Collaborations & MNC Presence
# India is also a favored destination for global AI R&D.
# *   R&D centers of global tech giants like Google, Microsoft, IBM, and Amazon in India significantly contribute to local AI development, fostering research, talent, and technology transfer.
# *   Partnerships between Indian and international institutions further accelerate knowledge sharing and collaborative innovation.
#
# ## III. AI's Transformative Impact Across Key Indian Sectors
#
# The influence of AI is palpable across nearly every sector of the Indian economy, driving efficiency, accessibility, and innovation.
#
# ### A. Healthcare
# AI is revolutionizing healthcare delivery, especially critical in a country with diverse healthcare challenges.
# *   **Diagnosis & Personalized Treatment:** AI-powered diagnostics are enhancing accuracy in radiology, ophthalmology (e.g., detecting diabetic retinopathy), and pathology. Predictive analytics are being used for disease outbreak forecasting and personalized treatment plans.
# *   **Drug Discovery & Research:** AI algorithms accelerate the identification of potential drug candidates and streamline clinical trials.
# *   **Remote Patient Monitoring:** AI-enabled wearables and telemedicine platforms are bridging urban-rural healthcare gaps, providing remote consultations and continuous monitoring.
# *   **Administrative Efficiency:** Automating tasks like patient scheduling, record management, and claims processing frees up medical professionals.
#
# ### B. Agriculture
# For a nation deeply rooted in agriculture, AI offers groundbreaking solutions.
# *   **Precision Farming:** AI helps in crop yield prediction, soil health analysis, early pest and disease detection, and optimizing irrigation, leading to higher productivity and reduced waste.
# *   **Weather Forecasting:** Advanced AI models provide more accurate local weather forecasts, helping farmers make informed decisions about planting and harvesting.
# *   **Supply Chain Optimization:** AI reduces post-harvest losses, improves logistics, and connects farmers more efficiently to markets, ensuring better returns.
#
# ### C. Finance & Banking (FinTech)
# The FinTech sector in India is a major adopter of AI, enhancing security and accessibility.
# *   **Fraud Detection & Cybersecurity:** AI algorithms analyze vast transaction data to identify suspicious patterns and prevent financial fraud in real-time.
# *   **Personalized Banking & Wealth Management:** AI-driven tools offer tailored financial advice, product recommendations, and automated investment portfolios.
# *   **Credit Scoring & Lending:** AI expands access to credit for underserved populations by analyzing alternative data points to assess creditworthiness.
# *   **Chatbots & Customer Service:** AI-powered chatbots provide 24/7 customer support, resolve queries, and assist with transactions, improving efficiency and customer experience.
#
# ### D. Education (EdTech)
# AI is personalizing learning and making education more accessible.
# *   **Personalized Learning Paths:** Adaptive AI platforms analyze student performance to create customized learning modules and recommend relevant content.
# *   **Automated Grading & Feedback:** AI tools assist educators by automating the grading of assignments and providing immediate feedback to students.
# *   **Virtual Tutors & Language Learning:** AI-powered virtual tutors and language learning apps make education more engaging and accessible, even in remote areas.
#
# ### E. E-commerce & Retail
# From browsing to delivery, AI enhances the shopping experience.
# *   **Recommendation Engines:** AI algorithms analyze purchase history and browsing behavior to provide highly personalized product recommendations, boosting sales.
# *   **Logistics & Supply Chain Optimization:** AI optimizes delivery routes, manages inventory, and predicts demand, leading to faster and more efficient supply chains.
# *   **Customer Service Chatbots:** These bots handle routine customer queries, process returns, and provide instant support, improving customer satisfaction.
#
# ### F. Manufacturing & Industry 4.0
# AI is driving efficiency and automation in Indian factories.
# *   **Predictive Maintenance:** AI sensors monitor machine health to predict potential failures, reducing downtime and maintenance costs.
# *   **Quality Control & Automation:** AI-powered vision systems inspect products for defects, ensuring higher quality standards and automating production processes.
# *   **Robotics & Smart Factories:** AI integration is leading to the development of smart factories with increased automation, improved safety, and optimized production.
#
# ### G. Public Services & Smart Cities
# AI is instrumental in urban development and public service delivery.
# *   **Traffic Management & Urban Planning:** AI optimizes traffic flow, predicts congestion, and helps in urban planning by analyzing mobility patterns.
# *   **Waste Management:** AI-powered systems can optimize waste collection routes, sort waste, and monitor waste levels, leading to more efficient management.
# *   **Disaster Management:** AI assists in predictive analytics for natural disasters like floods and cyclones, improving early warning systems and response efforts.
#
# ## IV. Challenges and Considerations on the AI Journey
#
# Despite the immense promise, India's AI journey is not without its hurdles. Addressing these challenges is crucial for sustainable and equitable growth.
#
# ### A. Data Privacy, Security, & Governance
# With vast datasets fueling AI, robust frameworks are essential.
# *   **Need for robust legal frameworks:** The ongoing efforts for a comprehensive Data Protection Bill are critical to establish clear guidelines for data collection, storage, and processing.
# *   **Ethical concerns around data collection and usage:** Ensuring transparency and consent in data practices is paramount to maintain public trust.
# *   **Cybersecurity threats and data breaches:** As AI systems become more central, they become targets, necessitating advanced cybersecurity measures.
#
# ### B. Skill Gap & Workforce Readiness
# While talent is abundant, specific AI skills are still in demand.
# *   **Need for continuous upskilling and reskilling programs:** The existing workforce needs training to adapt to AI-driven changes and fill new roles.
# *   **Bridging the gap between academic learning and industry demands:** Universities need to align curricula more closely with the practical skills required by the AI industry.
# *   **Fear of job displacement and the need for social safety nets:** Addressing anxieties about AI-induced job losses through retraining initiatives and social support programs is vital.
#
# ### C. Infrastructure & Accessibility
# The digital divide remains a significant barrier.
# *   **Digital divide:** Uneven internet access, particularly in remote and rural areas, limits AI's reach.
# *   **Affordability of AI technologies for SMEs:** Small and medium enterprises often struggle with the cost of implementing AI solutions.
# *   **Availability of high-performance computing resources:** AI development, especially for complex models, requires significant computational power, which can be costly and not universally available.
#
# ### D. Ethical AI & Bias
# Ensuring fairness and preventing discrimination are critical.
# *   **Ensuring fairness, transparency, and accountability in AI algorithms:** Algorithms must be designed to be unbiased and their decisions explainable, especially in critical applications.
# *   **Addressing inherent biases in training data:** Training data can reflect societal biases (e.g., gender, caste, region), leading to discriminatory AI outcomes if not carefully mitigated.
# *   **Developing explainable AI (XAI) for critical applications:** Understanding *why* an AI makes a particular decision is crucial for trust and compliance, particularly in healthcare, finance, and legal domains.
#
# ### E. Research & Development Investment
# India needs to boost its foundational AI research.
# *   **Increasing public and private sector investment in fundamental AI research:** Moving beyond application-focused development to basic research is key for long-term innovation leadership.
# *   **Fostering a culture of deep tech innovation:** Encouraging groundbreaking research that pushes the boundaries of AI capabilities.
#
# ### F. Regulatory Sandbox & Policy Agility
# The pace of technological change demands flexible governance.
# *   **Need for adaptable regulations that keep pace with rapid technological advancements:** Rigid laws can stifle innovation; agile regulatory sandboxes allow for experimentation in controlled environments.
#
# ## V. The Road Ahead: Future Outlook & Opportunities
#
# India's journey with AI is still in its early chapters, but the future promises even more profound transformations.
#
# ### A. India as a Global AI Hub
# The potential is immense for India to emerge as a global leader in AI.
# *   **Potential to export AI solutions and services globally:** Leveraging its talent pool, India can develop and export innovative AI products and services worldwide.
# *   **Attracting more international investment and talent:** A robust AI ecosystem will continue to draw foreign capital and skilled professionals.
#
# ### B. AI for Inclusive Growth ("AI for Bharat")
# India is uniquely positioned to demonstrate how AI can serve a diverse, large population.
# *   **Leveraging AI to solve India's unique social and economic challenges:** From eradicating poverty to improving public health, AI can be a powerful tool for large-scale societal good.
# *   **Focus on regional language processing, localized solutions:** Breaking language barriers and developing AI solutions tailored to specific regional contexts and needs.
# *   **Empowering remote communities through AI-driven services:** Extending the reach of education, healthcare, and financial services to previously underserved populations.
#
# ### C. Emergence of New AI-Driven Industries & Jobs
# AI will be a job creator, not just a disruptor.
# *   **Creation of specialized roles in AI development, ethics, and deployment:** New jobs will emerge in areas like AI auditing, prompt engineering, and ethical AI oversight.
# *   **Growth of AI-powered personalized services:** From hyper-personalized education to customized wellness programs, AI will enable new service industries.
#
# ### D. Greater Public-Private Partnerships
# Collaboration will be the cornerstone of future growth.
# *   **Collaboration between government, academia, and industry to accelerate innovation:** Joint initiatives can pool resources, share expertise, and drive rapid advancements.
# *   **Joint initiatives for skilling and infrastructure development:** Working together to build the necessary talent and digital backbone.
#
# ### E. Focus on Responsible AI Deployment
# Ethical considerations will remain central to India's AI strategy.
# *   Prioritizing ethical guidelines and frameworks as AI matures, ensuring AI serves humanity responsibly and inclusively.
#
# ## VI. Conclusion: India's Intelligent Leap
#
# India's rise in Artificial Intelligence is a narrative of ambition, innovation, and strategic foresight. We've explored the potent catalysts—from decisive government policies and a burgeoning startup scene to an unmatched talent pool and an ocean of digital data—that have propelled AI to the forefront of India's development agenda. We've witnessed AI's transformative impact across crucial sectors like healthcare, agriculture, finance, and education, showcasing its potential to address complex "Bharat-scale" challenges. Yet, we've also acknowledged the significant hurdles, from ensuring data privacy and bridging the skill gap to fostering ethical AI and investing in robust R&D.
#
# India's AI journey is not merely about technological advancement; it is a profound societal transformation and economic empowerment. The vision for an AI-powered India is one where technology contributes to a more efficient, equitable, and prosperous nation, where innovation serves the many, not just the few. As India continues to embrace and shape the AI revolution, its leadership in developing responsible, inclusive, and scalable AI solutions could set a global precedent.
#
# What role do you envision AI playing in shaping the next decade of India's growth, and how can we collectively ensure AI's benefits reach every corner of India responsibly? The intelligent leap has begun, and India is ready to lead the charge into a smarter, more connected future.
#
# ---
#
# ## VII. Additional Resources (Optional)
#
# *   **NITI Aayog's National Strategy for Artificial Intelligence:** [Link to NITI Aayog report, if publicly available]
# *   **RAISE 2020 Summit Highlights:** [Link to summary/videos from the summit]
# *   **Reports on India's Startup Ecosystem:** [Links to relevant reports from Nasscom, Inc42, etc.]
# *   **Updates on India's Data Protection Bill:** [Links to government resources or reputable news articles]
